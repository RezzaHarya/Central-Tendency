# %% [markdown]
# <a href="https://colab.research.google.com/github/RezzaHarya/Central-Tendency/blob/main/tugasprak3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data3295 = pd.read_csv('Data Statistika Nilai 40 siswa.csv')
print("Tampilan Data Awal:")
display(data3295)
# Out:
# Tampilan Data Awal:
#     70
# 0   80
# 1   85
# 2   60
# 3   55
# 4   50
# 5   50
# 6   60
# 7   70
# 8   80
# 9   60
# 10  60
# 11  85
# 12  60
# 13  70
# 14  75
# 15  80
# 16  60
# 17  60
# 18  50
# 19  70
# 20  85
# 21  85
# 22  60
# 23  60
# 24  90
# 25  95
# 26  90
# 27  55
# 28  45
# 29  45
# 30  50
# 31  60
# 32  80
# 33  95
# 34  65
# 35  65
# 36  55
# 37  75
# 38  85

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
mean5789 = data3295['70'].mean()
print('Mean of the dataset:')
print(data3295
 ['70'].mean())

plt.hist(data3295['70'], bins=10, edgecolor='white')
plt.title('Histogram of Data')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()
# Out:
# Mean of the dataset:
# 68.2051282051282

# %%
median5789 = data3314['70'].median()
print('Median of the dataset:')
print(data3314['70'].median())

plt.hist(data3314['70'], bins=10, edgecolor='white')
plt.title('Histogram of Data')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()
# Out:
# Median of the dataset:
# 65.0

# %%
modus5789 = data3314['70'].mode()
print('Mode of the dataset:')
print(data3314['70'].mode())

plt.hist(data3314['70'], bins=10, edgecolor='white')
plt.title('Histogram of Data')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()
# Out:
# Mode of the dataset:
# 0    60
# Name: 70, dtype: int64
